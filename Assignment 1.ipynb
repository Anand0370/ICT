# %%
#importing the required packages
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the dataset to python environment

# %%
#loading the given excel data 
data = pd.read_excel('iris.xls')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculate the mean of each column of the dataset.

# %%
#creating dataframe using the given data
df = pd.DataFrame(data)
df.mean(axis=0,numeric_only=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Check for the null values present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().any(axis=0)
#df.isnull().sum()
# Out:
# SL                False
# SW                False
# PL                False
# PW                False
# Classification    False
# dtype: bool

# %% [markdown]
# # Perform meaningful visualizations using the dataset.

# %% [markdown]
# # Countplot

# %%
#setting the required plot style
plt.style.use('seaborn')
sns.countplot(x ='Classification', data = df )
#adding labels for x and y axis
plt.xlabel('Classification', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
#adding tiltle for graph
plt.title('Iris Data Count', fontsize = 20)
#setting the required limits for x and y axis
plt.ylim(bottom = 0, top = 100)
#adjusting x and y ticks size
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.show();

# %% [markdown]
# # Boxplot

# %%
#setting the required plot style
plt.style.use('bmh')
#Defining a function graph()
def graph(y):
    sns.boxplot(x = 'Classification', y = y , data = df)
    plt.xlabel('Classification', fontsize = 18)
    plt.ylabel( y, fontsize = 18)
plt.figure(figsize=(20,20))
#plotting subplots using the function graph()
plt.subplot(221)
graph('SL')
plt.subplot(222)
graph('SW')
plt.subplot(223)
graph('PL')
plt.subplot(224)
graph('PW')
plt.show();

# %% [markdown]
# # Violinplot

# %%
#setting the required plot style
plt.style.use('ggplot')
#Defining a function graph()
def graph(y):
    sns.violinplot(x = 'Classification', y = y , data = df)
    plt.xlabel('Classification', fontsize = 15)
    plt.ylabel( y, fontsize = 15)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
plt.figure(figsize=(15,15))
#plotting subplots using the function graph()
plt.subplot(221)
graph('SL')
plt.subplot(222)
graph('SW')
plt.subplot(223)
graph('PL')
plt.subplot(224)
graph('PW')
plt.show();

# %% [markdown]
# # Scatterplot

# %%
#setting the required plot style
plt.style.use('classic')
def graph(x,y):
    sns.scatterplot(x = x, y = y , hue= 'Classification' , data = df, sizes=(40,40))
    plt.title((x,'vs',y), fontsize = 20)
    plt.xlabel( x, fontsize = 15)
    plt.ylabel( y, fontsize = 15)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
plt.figure(figsize=(20,20))
plt.subplot(221)
graph('SL','SW')
plt.subplot(222)
graph('PL','PW')
plt.show();

# %% [markdown]
# # Pairplot

# %%
#setting the required plot style
plt.style.use('seaborn')
sns.pairplot(hue='Classification', data=df);
plt.show()

# %% [markdown]
# # Correlation

# %%
data.corr(method='pearson')
# Out:
#           SL        SW        PL        PW
# SL  1.000000 -0.109369  0.871754  0.817954
# SW -0.109369  1.000000 -0.420516 -0.356544
# PL  0.871754 -0.420516  1.000000  0.962757
# PW  0.817954 -0.356544  0.962757  1.000000
